# %% [markdown]
# 画像を指定して、napariを起動させる

# %%
from skimage import data # sample data
import napari

# %%
viewer, image_layer = napari.imshow(data.astronaut())

if __name__ == '__main__':
    napari.run()

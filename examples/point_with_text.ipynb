# %%
import napari
from napari.layers.utils.text_manager import TextManager

# %% [markdown]
# 文字に使えるオプションをすべて表示するには以下のようにします。

# %%
print(TextManager.model_fields)
# Out:
# {'string': FieldInfo(annotation=StringEncoding, required=False, default=ConstantStringEncoding(constant=array('', dtype='<U1'), encoding_type='ConstantStringEncoding')), 'color': FieldInfo(annotation=ColorEncoding, required=False, default=ConstantColorEncoding(constant=ColorValue([0., 1., 1., 1.], dtype=float32), encoding_type='ConstantColorEncoding')), 'visible': FieldInfo(annotation=bool, required=False, default=True), 'size': FieldInfo(annotation=float, required=False, default=12, metadata=[Gt(gt=0)]), 'scaling': FieldInfo(annotation=bool, required=False, default=False), 'blending': FieldInfo(annotation=Blending, required=False, default=<Blending.TRANSLUCENT: 'translucent'>), 'anchor': FieldInfo(annotation=Anchor, required=False, default=<Anchor.CENTER: 'center'>), 'translation': FieldInfo(annotation=Array, required=False, default=0), 'rotation': FieldInfo(annotation=float, required=False, default=0)}

# %% [markdown]
# - [napari.components.ViewerModel — napari](https://napari.org/stable/api/napari.components.ViewerModel.html#napari.components.ViewerModel.add_points)
# - [Add points with text — napari](https://napari.org/stable/gallery/add_points_with_text.html)
